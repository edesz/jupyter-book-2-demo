# %% [markdown]
# ---
# authors:
#   - edesz
#   - joscary
# date: 2025-10-09
# ---

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Imports

# %% [markdown]
# All requires Python libraries are imported below

# %%
import altair as alt
import pandas as pd

# %% [markdown]
# Below are `altair` settings required to support plotting large datasets and customize appearance

# %%
_ = alt.data_transformers.enable("vegafusion")
_ = alt.renderers.set_embed_options(actions=False)

# %% [markdown]
# ## About

# %% [markdown]
# Perform EDA.

# %% [markdown]
# ## User Inputs

# %%
url = "https://vegafusion-datasets.s3.amazonaws.com/vega/movies_201k.parquet"

# %% [markdown]
# ## Get Data

# %%
# %%time
df = pd.read_parquet(url)
df.head()
# Out:
# CPU times: user 158 ms, sys: 47.8 ms, total: 206 ms
# Wall time: 427 ms
#    index                       Title   US_Gross  Worldwide_Gross  \
# 0      0              The Land Girls   146083.0         146083.0
# 1      1      First Love, Last Rites    10876.0          10876.0
# 2      2  I Married a Strange Person   203134.0         203134.0
# 3      3        Let's Talk About Sex   373615.0         373615.0
# 4      4                        Slam  1009819.0        1087521.0
#
#    US_DVD_Sales  Production_Budget Release_Date MPAA_Rating  Running_Time_min  \
# 0           NaN          8000000.0  Jun 12 1998           R               NaN
# 1           NaN           300000.0  Aug 07 1998           R               NaN
# 2           NaN           250000.0  Aug 28 1998         NaN               NaN
# 3           NaN           300000.0  Sep 11 1998         NaN               NaN
# 4           NaN          1000000.0  Oct 09 1998           R               NaN
#
#   Distributor               Source Major_Genre         Creative_Type Director  \
# 0    Gramercy                  NaN         NaN                   NaN      NaN
# 1      Strand                  NaN       Drama                   NaN      NaN
# 2   Lionsgate                  NaN      Comedy                   NaN      NaN
# 3   Fine Line                  NaN      Comedy                   NaN      NaN
# 4     Trimark  Original Screenplay       Drama  Contemporary Fiction      NaN
#
#    Rotten_Tomatoes_Rating  IMDB_Rating  IMDB_Votes
# 0                     NaN          6.1      1071.0
# 1                     NaN          6.9       207.0
# 2                     NaN          6.8       865.0
# 3                    13.0          NaN         NaN
# 4                    62.0          3.4       165.0

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Distributions of Numerical Features

# %% [markdown]
# Show a bar chart of all movie ratings

# %%
chart = (
    alt.Chart(df)
    .mark_bar()
    .encode(
        alt.X("IMDB_Rating:Q", bin=alt.Bin(maxbins=75)),
        y="count()",
    )
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Relationships of Numerical Features

# %%
# %%time
chart = alt.Chart(df).mark_rect().encode(
    alt.X('IMDB_Rating:Q', bin=alt.Bin(maxbins=60)),
    alt.Y('Rotten_Tomatoes_Rating:Q', bin=alt.Bin(maxbins=40)),
    alt.Color('count():Q', scale=alt.Scale(scheme='greenblue'))
)
chart
# Out:
# CPU times: user 843 μs, sys: 0 ns, total: 843 μs
# Wall time: 848 μs
# alt.Chart(...)
